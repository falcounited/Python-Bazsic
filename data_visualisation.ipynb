# %% [markdown]
# <a href="https://colab.research.google.com/github/falcounited/Python-Bazsic/blob/main/data_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=["a","b","c","d"]
y=[1,2,3,4]

# %%
#piechart
x=["support","no support","no comment"]
y= [60,30,10]
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x791aa5309000>,
#   <matplotlib.patches.Wedge at 0x791aa530b040>,
#   <matplotlib.patches.Wedge at 0x791aa5309810>],
#  [Text(-0.33991877217145816, 1.046162142464278, 'support'),
#   Text(2.0597886522865473e-07, -1.0999999999999808, 'no support'),
#   Text(1.0461622458970796, -0.339918453837944, 'no comment')])

# %%
#scatter
import numpy as np

x=np.random.randn(100)
y=np.random.random(100)
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris = sns.load_dataset  ("iris")

# %%
sns.lineplot(data=iris,x="sepal_length", y= "petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(data=iris,x="sepal_length", y= "petal_length",hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.regplot(data=iris,x="sepal_length", y= "petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.jointplot(data=iris,x="sepal_length", y= "petal_length")

# %%
sns.pairplot(data=iris)
